# %%
# %load_ext autoreload
# %autoreload 2

# %%
from multicamera_airflow_pipeline.jonah_241112.compression import VideoCompressor
from pathlib import Path
# Out:
# INFO:multicamera_airflow_pipeline.jonah_241112.compression:Python interpreter binary location: /home/jop9552/miniconda3/envs/dataPy_NWB2/bin/python

# %%
# set logging level to debug
import logging
logging.basicConfig(level=logging.DEBUG)

rec_dir = log_dir = Path("/n/groups/datta/Jonah/20241121_methimazole_cfos/raw_data/J08601/20241205_J08601_TRIM")
VC = VideoCompressor(
    rec_dir,
    log_dir,
    preset="ultrafast",  #just for testing
    patterns_to_exclude_from_vids=["azure"] # test on a trimmed video, so we dont want to exclude "TRIM"
    )

# %%
VC.run()
# Out:
# INFO:multicamera_airflow_pipeline.jonah_241112.compression:Processing 1 videos
# INFO:multicamera_airflow_pipeline.jonah_241112.compression:Running compression on /n/groups/datta/Jonah/20241121_methimazole_cfos/raw_data/J08601/20241205_J08601_TRIM/20241205_J08601.side3.0_TRIM.mp4 with presest ultrafast
# INFO:multicamera_airflow_pipeline.jonah_241112.compression:Original framerate detected: 120.00479950456727 fps
# INFO:multicamera_airflow_pipeline.jonah_241112.compression:Output video will be saved to: /n/groups/datta/Jonah/20241121_methimazole_cfos/raw_data/J08601/20241205_J08601_TRIM/20241205_J08601.side3.0_TRIM.tmp.mp4
# INFO:multicamera_airflow_pipeline.jonah_241112.compression:The original video will be replaced with the compressed video!
# ...

# %%
from multicamera_airflow_pipeline.jonah_241112.compression import VideoCompressor
from pathlib import Path
rec_dir = log_dir = Path("/n/groups/datta/Jonah/20241121_methimazole_cfos/raw_data/J08601/20241205_J08601_TRIM")
VC = VideoCompressor(
    rec_dir,
    log_dir,
    patterns_to_exclude_from_vids=["azure"]
    )
VC.run()
