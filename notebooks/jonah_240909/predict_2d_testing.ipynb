# %%
# conda env: mmdeploy

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import logging
from pathlib import Path
import sys

import torch
import yaml

logging.basicConfig(level=logging.DEBUG)
logger = logging.getLogger(__name__)
logger.info(f"Python interpreter binary location: {sys.executable}")
# Out:
# INFO:__main__:Python interpreter binary location: /home/jop9552/miniconda3/envs/mmdeploy_JP_v2/bin/python

# %%
torch.cuda.is_available()
# Out:
# True

# %%
# config_file =  "/n/groups/datta/Jonah/Local_code_groups/6cam_repos/multicam_airflow_pipeline/multicamera_airflow_pipeline/tim_240731/default_config.yaml"
config_file =  "/n/groups/datta/Jonah/Local_code_groups/6cam_repos/multicam_airflow_pipeline/multicamera_airflow_pipeline/jonah_241112/default_config_v2.yaml"
config_file = Path(config_file)
config = yaml.safe_load(open(config_file, "r"))

for kw in ["use_tensorrt", "tensorrt_rtmdetection_model_name", "tensorrt_rtmpose_model_name"]:
    if kw in config["prediction_2d"]:
        config["prediction_2d"].pop(kw)

# rec_dir = "/n/groups/datta/Jonah/20240925_PBN_npx/raw_data/J07901/20240930_J07901_6cam_PBN/24-09-30-15-43-47-490092"
# output_directory_predictions = join(rec_dir, "tmp_2d_preds")
# expected_video_length_frames = 432017
rec_dir = "/n/groups/datta/Jonah/20240206_methimazole_sniffing/20240206_6cam/data/J04502/20240426_J04502"
output_directory_predictions = "/n/groups/datta/kpts_pipeline/jonah_241112/results/2D_predictions/20240426_J04502"
expected_video_length_frames = 7200000
tensorrt_model_directory = "/n/groups/datta/kpts_pipeline/jonah_241112/results/tensorrt/"

# %%
# grab sync cameras function
from multicamera_airflow_pipeline.jonah_241112.keypoints.predict_2D import Inferencer2D

inferencer = Inferencer2D(
    recording_directory = rec_dir, 
    output_directory_predictions = output_directory_predictions,
    expected_video_length_frames = expected_video_length_frames,
    tensorrt_model_directory=tensorrt_model_directory,
    tensorrt_rtmdetection_model_name="rtmdet_small_8xb32-300e_coco_chronic_24-10-31-12-48-26",
    tensorrt_rtmpose_model_name="rtmpose-m_8xb64-210e_ap10k-256x256_24-11-01-20-36-55",
    use_tensorrt=True,
    **config["prediction_2d"]
)
# Out:
# INFO:multicamera_airflow_pipeline.jonah_241112.keypoints.predict_2D:Python interpreter binary location: /home/jop9552/miniconda3/envs/mmdeploy_JP_v2/bin/python
# INFO:multicamera_airflow_pipeline.jonah_241112.keypoints.predict_2D:Using CUDA device: NVIDIA_A40
# INFO:multicamera_airflow_pipeline.jonah_241112.keypoints.predict_2D:Using Tensorrt: True
# INFO:multicamera_airflow_pipeline.jonah_241112.keypoints.predict_2D:Using tensorrt, loading models
# INFO:multicamera_airflow_pipeline.jonah_241112.keypoints.predict_2D:Init completed

# %%
inferencer.run()
# Out:
# INFO:multicamera_airflow_pipeline.jonah_241112.keypoints.predict_2D:Running 2D inference over videos
# INFO:multicamera_airflow_pipeline.jonah_241112.keypoints.predict_2D:Video processing incomplete, running
# INFO:multicamera_airflow_pipeline.jonah_241112.keypoints.predict_2D:Processing 6 videos
# processing videos:   0%|          | 0/6 [00:00<?, ?it/s]
# module load gcc/9.2.0
# module load cuda/11.7
# TENSORRT_DIR=/n/groups/datta/Jonah/Local_code_groups/tensorrt_install/TensorRT-8.6.1.6
# export LD_LIBRARY_PATH=${TENSORRT_DIR}/lib:$LD_LIBRARY_PATH
# /home/jop9552/miniconda3/envs/mmdeploy_JP_v2/bin/python -c 'print('hello'); raise ValueError('testing')'
# INFO:multicamera_airflow_pipeline.jonah_241112.keypoints.predict_2D:Video failed /n/groups/datta/Jonah/20240206_methimazole_sniffing/20240206_6cam/data/J04502/20240426_J04502/20240426_J04502.bottom.mp4, writing to log file /n/groups/datta/kpts_pipeline/jonah_241112/results/2D_predictions/20240426_J04502/20240426_J04502.bottom.error.log
# > /n/groups/datta/Jonah/Local_code_groups/6cam_repos/multicam_airflow_pipeline/multicamera_airflow_pipeline/jonah_241112/keypoints/predict_2D.py(245)run()
#     243                         )
#     244                         import pdb; pdb.set_trace()
# --> 245                         with open(error_log_file, "w") as f:
#     246                             # Write both stdout and stderr to the file
#     247                             f.write("Standard Output:\n")
#
# '\nThe following have been reloaded with a version change:\n  1) gcc/6.2.0 => gcc/9.2.0\n\nTraceback (most recent call last):\n  File "<string>", line 1, in <module>\nNameError: name \'hello\' is not defined\n'
# '\nThe following have been reloaded with a version change:\n  1) gcc/6.2.0 => gcc/9.2.0\n\nTraceback (most recent call last):\n  File "<string>", line 1, in <module>\nNameError: name \'hello\' is not defined\n'
# PosixPath('/n/groups/datta/kpts_pipeline/jonah_241112/results/2D_predictions/20240426_J04502/20240426_J04502.bottom.error.log')
# > /n/groups/datta/Jonah/Local_code_groups/6cam_repos/multicam_airflow_pipeline/multicamera_airflow_pipeline/jonah_241112/keypoints/predict_2D.py(247)run()
#     245                         with open(error_log_file, "w") as f:
#     246                             # Write both stdout and stderr to the file
# --> 247                             f.write("Standard Output:\n")
#     248                             f.write(stdout)
#     249                             f.write("\n\nStandard Error:\n")
#
# > /n/groups/datta/Jonah/Local_code_groups/6cam_repos/multicam_airflow_pipeline/multicamera_airflow_pipeline/jonah_241112/keypoints/predict_2D.py(248)run()
#     246                             # Write both stdout and stderr to the file
#     247                             f.write("Standard Output:\n")
# --> 248                             f.write(stdout)
#     249                             f.write("\n\nStandard Error:\n")
#     250                             f.write(stderr)
#
# > /n/groups/datta/Jonah/Local_code_groups/6cam_repos/multicam_airflow_pipeline/multicamera_airflow_pipeline/jonah_241112/keypoints/predict_2D.py(249)run()
#     247                             f.write("Standard Output:\n")
#     248                             f.write(stdout)
# --> 249                             f.write("\n\nStandard Error:\n")
#     250                             f.write(stderr)
#     251                     else:
#
# > /n/groups/datta/Jonah/Local_code_groups/6cam_repos/multicam_airflow_pipeline/multicamera_airflow_pipeline/jonah_241112/keypoints/predict_2D.py(250)run()
#     248                             f.write(stdout)
#     249                             f.write("\n\nStandard Error:\n")
# --> 250                             f.write(stderr)
#     251                     else:
#     252                         # when completed, move to output file
#
# > /n/groups/datta/Jonah/Local_code_groups/6cam_repos/multicam_airflow_pipeline/multicamera_airflow_pipeline/jonah_241112/keypoints/predict_2D.py(254)run()
#     252                         # when completed, move to output file
#     253                         shutil.copy(temp_h5_path, output_h5_file)
# --> 254                     if os.path.exists(temp_h5_path):
#     255                         os.remove(temp_h5_path)
#     256                     # remove the log file
#
# > /n/groups/datta/Jonah/Local_code_groups/6cam_repos/multicam_airflow_pipeline/multicamera_airflow_pipeline/jonah_241112/keypoints/predict_2D.py(255)run()
#     253                         shutil.copy(temp_h5_path, output_h5_file)
#     254                     if os.path.exists(temp_h5_path):
# --> 255                         os.remove(temp_h5_path)
#     256                     # remove the log file
#     257                     if os.path.exists(log_file):
#
# > /n/groups/datta/Jonah/Local_code_groups/6cam_repos/multicam_airflow_pipeline/multicamera_airflow_pipeline/jonah_241112/keypoints/predict_2D.py(257)run()
#     255                         os.remove(temp_h5_path)
#     256                     # remove the log file
# --> 257                     if os.path.exists(log_file):
#     258                         os.remove(log_file)
#     259
#
# PosixPath('/n/groups/datta/kpts_pipeline/jonah_241112/results/2D_predictions/20240426_J04502/20240426_J04502.bottom.log')
# > /n/groups/datta/Jonah/Local_code_groups/6cam_repos/multicam_airflow_pipeline/multicamera_airflow_pipeline/jonah_241112/keypoints/predict_2D.py(258)run()
#     256                     # remove the log file
#     257                     if os.path.exists(log_file):
# --> 258                         os.remove(log_file)
#     259
#     260         logger.info(f"Completed processing {len(self.all_videos)} videos")
#
# > /n/groups/datta/Jonah/Local_code_groups/6cam_repos/multicam_airflow_pipeline/multicamera_airflow_pipeline/jonah_241112/keypoints/predict_2D.py(119)run()
#     117         assert len(self.all_videos) > 0, f"No videos found in {self.recording_directory}"
#     118
# --> 119         for video_path in tqdm(self.all_videos, desc="processing videos"):
#     120
#     121             output_h5_file = self.output_directory_predictions / f"{video_path.stem}.h5"
# processing videos:  17%|█▋        | 1/6 [01:28<07:20, 88.15s/it]
# > /n/groups/datta/Jonah/Local_code_groups/6cam_repos/multicam_airflow_pipeline/multicamera_airflow_pipeline/jonah_241112/keypoints/predict_2D.py(121)run()
#     119         for video_path in tqdm(self.all_videos, desc="processing videos"):
#     120
# --> 121             output_h5_file = self.output_directory_predictions / f"{video_path.stem}.h5"
#     122             if output_h5_file.exists() and not self.recompute_completed:
#     123                 # logger.info(f"Completed, skipping {video_path}")
#
# > /n/groups/datta/Jonah/Local_code_groups/6cam_repos/multicam_airflow_pipeline/multicamera_airflow_pipeline/jonah_241112/keypoints/predict_2D.py(122)run()
#     120
#     121             output_h5_file = self.output_directory_predictions / f"{video_path.stem}.h5"
# --> 122             if output_h5_file.exists() and not self.recompute_completed:
#     123                 # logger.info(f"Completed, skipping {video_path}")
#     124                 continue
#
# > /n/groups/datta/Jonah/Local_code_groups/6cam_repos/multicam_airflow_pipeline/multicamera_airflow_pipeline/jonah_241112/keypoints/predict_2D.py(129)run()
#     127             #   read the current time from the log file, and if it has been more than 1 day, then reprocess
#     128             #   this accounts for the case where a job is killed and the log file is not deleted.
# --> 129             log_file = self.output_directory_predictions / f"{video_path.stem}.log"
#     130             if self.ignore_log_files == False:
#     131                 if (self.recompute_completed == False) and (log_file.exists()):
#
# > /n/groups/datta/Jonah/Local_code_groups/6cam_repos/multicam_airflow_pipeline/multicamera_airflow_pipeline/jonah_241112/keypoints/predict_2D.py(130)run()
#     128             #   this accounts for the case where a job is killed and the log file is not deleted.
#     129             log_file = self.output_directory_predictions / f"{video_path.stem}.log"
# --> 130             if self.ignore_log_files == False:
#     131                 if (self.recompute_completed == False) and (log_file.exists()):
#     132                     with open(log_file, "r") as f:
#
# > /n/groups/datta/Jonah/Local_code_groups/6cam_repos/multicam_airflow_pipeline/multicamera_airflow_pipeline/jonah_241112/keypoints/predict_2D.py(139)run()
#     137             # create a log with the name of this video, to indicate that it is being processed
#     138             #   the log will have a timestamp
# --> 139             with open(log_file, "w") as f:
#     140                 f.write(f"{datetime.now()}\n")
#     141
#
# > /n/groups/datta/Jonah/Local_code_groups/6cam_repos/multicam_airflow_pipeline/multicamera_airflow_pipeline/jonah_241112/keypoints/predict_2D.py(140)run()
#     138             #   the log will have a timestamp
#     139             with open(log_file, "w") as f:
# --> 140                 f.write(f"{datetime.now()}\n")
#     141
#     142             # initially save output to temp file
#
# > /n/groups/datta/Jonah/Local_code_groups/6cam_repos/multicam_airflow_pipeline/multicamera_airflow_pipeline/jonah_241112/keypoints/predict_2D.py(143)run()
#     141
#     142             # initially save output to temp file
# --> 143             with tempfile.NamedTemporaryFile(suffix=".h5", delete=False) as temp_h5_file:
#     144                 temp_h5_path = temp_h5_file.name
#     145
#
# > /n/groups/datta/Jonah/Local_code_groups/6cam_repos/multicam_airflow_pipeline/multicamera_airflow_pipeline/jonah_241112/keypoints/predict_2D.py(144)run()
#     142             # initially save output to temp file
#     143             with tempfile.NamedTemporaryFile(suffix=".h5", delete=False) as temp_h5_file:
# --> 144                 temp_h5_path = temp_h5_file.name
#     145
#     146                 # update the signal handler for the current video log file
#
# > /n/groups/datta/Jonah/Local_code_groups/6cam_repos/multicam_airflow_pipeline/multicamera_airflow_pipeline/jonah_241112/keypoints/predict_2D.py(147)run()
#     145
#     146                 # update the signal handler for the current video log file
# --> 147                 update_log_file_signal_handler(log_file)
#     148
#     149                 if self.use_tensorrt == False:
#
# > /n/groups/datta/Jonah/Local_code_groups/6cam_repos/multicam_airflow_pipeline/multicamera_airflow_pipeline/jonah_241112/keypoints/predict_2D.py(149)run()
#     147                 update_log_file_signal_handler(log_file)
#     148
# --> 149                 if self.use_tensorrt == False:
#     150                     try:
#     151                         logger.info(f"Processing {video_path}")
#
# > /n/groups/datta/Jonah/Local_code_groups/6cam_repos/multicam_airflow_pipeline/multicamera_airflow_pipeline/jonah_241112/keypoints/predict_2D.py(212)run()
#     210                     # )"""
#     211                     # )
# --> 212                     python_script = "print('hello'); raise ValueError('testing')"
#     213
#     214                     # print(sys.executable)
#
# > /n/groups/datta/Jonah/Local_code_groups/6cam_repos/multicam_airflow_pipeline/multicamera_airflow_pipeline/jonah_241112/keypoints/predict_2D.py(216)run()
#     214                     # print(sys.executable)
#     215                     # Run the process and capture the output
# --> 216                     command = ""
#     217                     command += "module load gcc/9.2.0\n"
#     218                     command += "module load cuda/11.7\n"
#
# > /n/groups/datta/Jonah/Local_code_groups/6cam_repos/multicam_airflow_pipeline/multicamera_airflow_pipeline/jonah_241112/keypoints/predict_2D.py(217)run()
#     215                     # Run the process and capture the output
#     216                     command = ""
# --> 217                     command += "module load gcc/9.2.0\n"
#     218                     command += "module load cuda/11.7\n"
#     219                     command += f"TENSORRT_DIR={self.tensorrt_dir}\n"
#
# > /n/groups/datta/Jonah/Local_code_groups/6cam_repos/multicam_airflow_pipeline/multicamera_airflow_pipeline/jonah_241112/keypoints/predict_2D.py(218)run()
#     216                     command = ""
#     217                     command += "module load gcc/9.2.0\n"
# --> 218                     command += "module load cuda/11.7\n"
#     219                     command += f"TENSORRT_DIR={self.tensorrt_dir}\n"
#     220                     command += "export LD_LIBRARY_PATH=${TENSORRT_DIR}/lib:$LD_LIBRARY_PATH\n"
#
# > /n/groups/datta/Jonah/Local_code_groups/6cam_repos/multicam_airflow_pipeline/multicamera_airflow_pipeline/jonah_241112/keypoints/predict_2D.py(219)run()
#     217                     command += "module load gcc/9.2.0\n"
#     218                     command += "module load cuda/11.7\n"
# --> 219                     command += f"TENSORRT_DIR={self.tensorrt_dir}\n"
#     220                     command += "export LD_LIBRARY_PATH=${TENSORRT_DIR}/lib:$LD_LIBRARY_PATH\n"
#     221                     # command += 'eval "$(conda shell.bash hook)";\n'
#
# > /n/groups/datta/Jonah/Local_code_groups/6cam_repos/multicam_airflow_pipeline/multicamera_airflow_pipeline/jonah_241112/keypoints/predict_2D.py(220)run()
#     218                     command += "module load cuda/11.7\n"
#     219                     command += f"TENSORRT_DIR={self.tensorrt_dir}\n"
# --> 220                     command += "export LD_LIBRARY_PATH=${TENSORRT_DIR}/lib:$LD_LIBRARY_PATH\n"
#     221                     # command += 'eval "$(conda shell.bash hook)";\n'
#     222                     # command += f"conda activate {self.conda_env};\n"
#
# > /n/groups/datta/Jonah/Local_code_groups/6cam_repos/multicam_airflow_pipeline/multicamera_airflow_pipeline/jonah_241112/keypoints/predict_2D.py(223)run()
#     221                     # command += 'eval "$(conda shell.bash hook)";\n'
#     222                     # command += f"conda activate {self.conda_env};\n"
# --> 223                     command += f"{sys.executable} -c '{python_script}'"
#     224                     print(command)
#     225                     process = subprocess.Popen(
#
# module load gcc/9.2.0
# module load cuda/11.7
# TENSORRT_DIR=/n/groups/datta/Jonah/Local_code_groups/tensorrt_install/TensorRT-8.6.1.6
# export LD_LIBRARY_PATH=${TENSORRT_DIR}/lib:$LD_LIBRARY_PATH
# /home/jop9552/miniconda3/envs/mmdeploy_JP_v2/bin/python -c 'print('hello'); raise ValueError('testing')'
# INFO:multicamera_airflow_pipeline.jonah_241112.keypoints.predict_2D:Video failed /n/groups/datta/Jonah/20240206_methimazole_sniffing/20240206_6cam/data/J04502/20240426_J04502/20240426_J04502.side1.mp4, writing to log file /n/groups/datta/kpts_pipeline/jonah_241112/results/2D_predictions/20240426_J04502/20240426_J04502.side1.error.log
# > /n/groups/datta/Jonah/Local_code_groups/6cam_repos/multicam_airflow_pipeline/multicamera_airflow_pipeline/jonah_241112/keypoints/predict_2D.py(245)run()
#     243                         )
#     244                         import pdb; pdb.set_trace()
# --> 245                         with open(error_log_file, "w") as f:
#     246                             # Write both stdout and stderr to the file
#     247                             f.write("Standard Output:\n")
# processing videos:  33%|███▎      | 2/6 [01:58<03:36, 54.14s/it]
# module load gcc/9.2.0
# module load cuda/11.7
# TENSORRT_DIR=/n/groups/datta/Jonah/Local_code_groups/tensorrt_install/TensorRT-8.6.1.6
# export LD_LIBRARY_PATH=${TENSORRT_DIR}/lib:$LD_LIBRARY_PATH
# /home/jop9552/miniconda3/envs/mmdeploy_JP_v2/bin/python -c 'print('hello'); raise ValueError('testing')'
# INFO:multicamera_airflow_pipeline.jonah_241112.keypoints.predict_2D:Video failed /n/groups/datta/Jonah/20240206_methimazole_sniffing/20240206_6cam/data/J04502/20240426_J04502/20240426_J04502.side2.mp4, writing to log file /n/groups/datta/kpts_pipeline/jonah_241112/results/2D_predictions/20240426_J04502/20240426_J04502.side2.error.log
# > /n/groups/datta/Jonah/Local_code_groups/6cam_repos/multicam_airflow_pipeline/multicamera_airflow_pipeline/jonah_241112/keypoints/predict_2D.py(244)run()
#     242                             f"Video failed {video_path}, writing to log file {error_log_file}"
#     243                         )
# --> 244                         import pdb; pdb.set_trace()
#     245                         with open(error_log_file, "w") as f:
#     246                             # Write both stdout and stderr to the file
# processing videos:  50%|█████     | 3/6 [02:04<01:36, 32.19s/it]
# module load gcc/9.2.0
# module load cuda/11.7
# TENSORRT_DIR=/n/groups/datta/Jonah/Local_code_groups/tensorrt_install/TensorRT-8.6.1.6
# export LD_LIBRARY_PATH=${TENSORRT_DIR}/lib:$LD_LIBRARY_PATH
# /home/jop9552/miniconda3/envs/mmdeploy_JP_v2/bin/python -c 'print('hello'); raise ValueError('testing')'
# INFO:multicamera_airflow_pipeline.jonah_241112.keypoints.predict_2D:Video failed /n/groups/datta/Jonah/20240206_methimazole_sniffing/20240206_6cam/data/J04502/20240426_J04502/20240426_J04502.side3.mp4, writing to log file /n/groups/datta/kpts_pipeline/jonah_241112/results/2D_predictions/20240426_J04502/20240426_J04502.side3.error.log
# > /n/groups/datta/Jonah/Local_code_groups/6cam_repos/multicam_airflow_pipeline/multicamera_airflow_pipeline/jonah_241112/keypoints/predict_2D.py(245)run()
#     243                         )
#     244                         import pdb; pdb.set_trace()
# --> 245                         with open(error_log_file, "w") as f:
#     246                             # Write both stdout and stderr to the file
#     247                             f.write("Standard Output:\n")
# processing videos:  67%|██████▋   | 4/6 [02:08<00:42, 21.18s/it]
# module load gcc/9.2.0
# module load cuda/11.7
# TENSORRT_DIR=/n/groups/datta/Jonah/Local_code_groups/tensorrt_install/TensorRT-8.6.1.6
# export LD_LIBRARY_PATH=${TENSORRT_DIR}/lib:$LD_LIBRARY_PATH
# /home/jop9552/miniconda3/envs/mmdeploy_JP_v2/bin/python -c 'print('hello'); raise ValueError('testing')'
# INFO:multicamera_airflow_pipeline.jonah_241112.keypoints.predict_2D:Video failed /n/groups/datta/Jonah/20240206_methimazole_sniffing/20240206_6cam/data/J04502/20240426_J04502/20240426_J04502.side4.mp4, writing to log file /n/groups/datta/kpts_pipeline/jonah_241112/results/2D_predictions/20240426_J04502/20240426_J04502.side4.error.log
# > /n/groups/datta/Jonah/Local_code_groups/6cam_repos/multicam_airflow_pipeline/multicamera_airflow_pipeline/jonah_241112/keypoints/predict_2D.py(244)run()
#     242                             f"Video failed {video_path}, writing to log file {error_log_file}"
#     243                         )
# --> 244                         import pdb; pdb.set_trace()
#     245                         with open(error_log_file, "w") as f:
#     246                             # Write both stdout and stderr to the file
# processing videos:  83%|████████▎ | 5/6 [02:09<00:13, 13.95s/it]
# module load gcc/9.2.0
# module load cuda/11.7
# TENSORRT_DIR=/n/groups/datta/Jonah/Local_code_groups/tensorrt_install/TensorRT-8.6.1.6
# export LD_LIBRARY_PATH=${TENSORRT_DIR}/lib:$LD_LIBRARY_PATH
# /home/jop9552/miniconda3/envs/mmdeploy_JP_v2/bin/python -c 'print('hello'); raise ValueError('testing')'
# INFO:multicamera_airflow_pipeline.jonah_241112.keypoints.predict_2D:Video failed /n/groups/datta/Jonah/20240206_methimazole_sniffing/20240206_6cam/data/J04502/20240426_J04502/20240426_J04502.top.mp4, writing to log file /n/groups/datta/kpts_pipeline/jonah_241112/results/2D_predictions/20240426_J04502/20240426_J04502.top.error.log
# > /n/groups/datta/Jonah/Local_code_groups/6cam_repos/multicam_airflow_pipeline/multicamera_airflow_pipeline/jonah_241112/keypoints/predict_2D.py(245)run()
#     243                         )
#     244                         import pdb; pdb.set_trace()
# --> 245                         with open(error_log_file, "w") as f:
#     246                             # Write both stdout and stderr to the file
#     247                             f.write("Standard Output:\n")
# processing videos: 100%|██████████| 6/6 [02:13<00:00, 22.21s/it]
# INFO:multicamera_airflow_pipeline.jonah_241112.keypoints.predict_2D:Completed processing 6 videos
# INFO:multicamera_airflow_pipeline.jonah_241112.keypoints.predict_2D:Completed 0 out of 6 videos
# INFO:multicamera_airflow_pipeline.jonah_241112.keypoints.predict_2D:Not all videos completed, not writing completed.log
